# %%
import pandas as pd
import pickle
import dateutil.parser
from datetime import *

# %%
user_file_path = 'E:\\SocialNetworks\\project\\user_dic.pkl'
review_file_path = 'E:\\SocialNetworks\\project\\myReview_new.pkl'
user_file = open(user_file_path,'r')
review_file = open(review_file_path,'r')
user_data = pickle.load(user_file)
review_data = pickle.load(review_file)

# %%
user_df_file_path = 'E:\\SocialNetworks\\project\\myUser.pkl'
user_df_file = open(user_df_file_path,'r')
user_df_data = pickle.load(user_df_file)

# %%
review_data.head(2)
# Out:
#               business_id       date               review_id  stars  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA 2007-05-17  15SdjuK7DmYqUAj6rjGowg      5
# 1  vcNAWiLM4dR7D2nwwJ7nCA 2010-03-22  RF6UnRTtG7tWMcrO2GEoAg      2
#
#                   user_id                                    votes
# 0  Xqd0DzHaiyRqVH3WRG7hzg  {u'funny': 0, u'useful': 2, u'cool': 1}
# 1  H1kH6QZV7Le4zqTRNxoZow  {u'funny': 0, u'useful': 2, u'cool': 0}

# %%
print "HI"
# Out:
# HI

# %%
#compute review_dict
review_dict = {} #dictionary of user -> list of his reviews
for i in range(len(review_data)):
    curr_userid = review_data['user_id'][i]
    review_dic = {}
    review_dic['votes'] = review_data['votes'][i]
    review_dic['user_id'] = review_data['user_id'][i]
    review_dic['review_id'] = review_data['review_id'][i]
    review_dic['stars'] = review_data['stars'][i]
    review_dic['business_id'] = review_data['business_id'][i]
    review_dic['date'] = review_data['date'][i]
    if curr_userid in review_dict.keys():
        rlist = review_dict[curr_userid]
        rlist.append(review_dic)
        review_dict[curr_userid] = rlist
    else:
        rlist = []
        rlist.append(review_dic)
        review_dict[curr_userid] = rlist
    if(i%100 == 0): print i
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
rev_file_path = 'E:\\SocialNetworks\\project\\RevDict.pkl'
rev_dict_file = open(rev_file_path,'w')
pickle.dump(review_dict,rev_dict_file)

# %%
for i in range(len(user_df_data)):
    curr_user_id = user_df_data['user_id'][i]
    curr_user_friends = user_df_data['friends'][i]
    curr_user_reviews = [] #get list of reviews by this user
    for j in range(len(review_data)):
        if(review_data['user_id'][j]==curr_user_id):
            curr_user_reviews.append({'review_id':review_data['review_id'][j],'business_id':review_data['business_id'][j],'date':review_data['date'][j],'stars':review_data['stars'][j]})
    for review in curr_user_reviews:
        curr_bus = review['business_id']
        for friend in curr_user_friends:
            friend_reviews = []
            print friend_reviews
            for k in range(len(review_data)):
                if(review_data['user_id'][j]==curr_user_id):
                    friend_reviews.append({'review_id':review_data['review_id'][j],'business_id':review_data['business_id'][j],'date':review_data['date'][j],'stars':review_data['stars'][j]})
            for f_review in friend_reviews:
                if(f_review['business_id'] == curr_bus):
                    print f_review
    print curr_user_reviews
    
    #print user_data['user_id'][i]
    print "HI"
    break
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
